# %% [markdown]
# # Electrostatic simulations with Elmer
# Here, we show how Elmer may be used to perform electrostatic simulations. For a given geometry, one needs to specify the terminals where to apply potential.
# The result is a Maxwell capacitance matrix. With no grounded conductor, the zero-flux outer boundary gives a floating network whose matrix rows sum to zero.
# For details on the physics, see {cite:p}`smolic_capacitance_2021`.
#
# ## Installation
# See [Elmer FEM – Installation](https://www.elmerfem.org/blog/binaries/) for installation or compilation instructions. Gplugins assumes `ElmerSolver`, `ElmerSolver_mpi`, and `ElmerGrid` are available in your PATH environment variable.
#
# Alternatively, [Singularity / Apptainer](https://apptainer.org/) containers may be used. An example definition file is found at [CSCfi/singularity-recipes](https://github.com/CSCfi/singularity-recipes/blob/main/elmer/elmer_9.0_csc.def) and can be built with:
# ```console
# singularity build elmer.sif <DEFINITION_FILE>.def
# ```
# Afterwards, an easy install method is to add scripts to `~/.local/bin` (or elsewhere in `PATH`) calling the Singularity container for each of the necessary executables. For example, one may create a `ElmerSolver_mpi` file containing
# ```console
# #!/bin/bash
# singularity exec <CONTAINER_LOCATION>/elmer.sif ElmerSolver_mpi $@
# ```
#
# ## Geometry, layer config and materials

# %%
from math import inf

import gdsfactory as gf
from gdsfactory.gpdk import LAYER, get_generic_pdk
from gdsfactory.technology import LayerStack
from gdsfactory.technology.layer_stack import LayerLevel
from meshwell.resolution import ConstantInField

from gplugins.elmer import run_capacitive_simulation_elmer

gf.config.rich_output()
PDK = get_generic_pdk()
PDK.activate()

# %% [markdown]
# We employ an example LayerStack used in superconducting circuits similar to {cite:p}`marxer_long-distance_2023`. The stack carries an explicit `vacuum` layer: the driver needs a named background volume, and `meshwell` no longer accepts `background_padding`.

# %%
layer_stack = LayerStack(
    layers=dict(
        substrate=LayerLevel(
            layer=LAYER.WAFER,
            thickness=500,
            zmin=0,
            material="Si",
            mesh_order=99,
        ),
        bw=LayerLevel(
            layer=LAYER.WG,
            thickness=200e-3,
            zmin=500,
            material="Nb",
            mesh_order=2,
        ),
        vacuum=LayerLevel(
            layer=LAYER.WAFER,
            thickness=700,
            zmin=500,
            material="vacuum",
            mesh_order=100,
        ),
    )
)
material_spec = {
    "Si": {"relative_permittivity": 11.45},
    "Nb": {"relative_permittivity": inf},
    "vacuum": {"relative_permittivity": 1},
}

# %% [markdown]
# `gf.components.interdigital_capacitor` draws the two interleaved combs as two disconnected polygons on `WG`, exposed as the terminals `o1` and `o2`. The enclosing `simulation_box` on `WAFER` defines the substrate and vacuum domain passed to the mesher.

# %%
simulation_box = [[-200, -200], [200, 200]]
c = gf.Component("capacitance_elmer")
cap = c << gf.components.interdigital_capacitor(
    fingers=4, finger_length=20, finger_gap=2, thickness=5, layer=LAYER.WG
)
c.add_ports(cap.ports)
(xmin, ymin), (xmax, ymax) = simulation_box
c.add_polygon(
    [(xmin, ymin), (xmax, ymin), (xmax, ymax), (xmin, ymax)], layer=LAYER.WAFER
)
c.plot()

# %% [markdown]
# ## Running the simulation
# ```{eval-rst}
# We use the function :func:`~run_capacitive_simulation_elmer`. This runs the simulation and returns an instance of :class:`~ElectrostaticResults` containing the capacitance matrix and a path to the mesh and the field solution.
# ```

# %%
help(run_capacitive_simulation_elmer)

# %% [markdown]
# ```{eval-rst}
# .. note::
#    The meshing parameters and element order shown here are very lax. As such, the computed capacitances are not very accurate.
# ```

# %%
results = run_capacitive_simulation_elmer(
    c,
    layer_stack=layer_stack,
    material_spec=material_spec,
    n_processes=1,
    element_order=1,
    simulation_folder="temporary",
    mesh_parameters=dict(
        background_tag="vacuum",
        default_characteristic_length=200,
        resolution_specs={
            "substrate": [ConstantInField(resolution=40, apply_to="volumes")],
            "vacuum": [ConstantInField(resolution=40, apply_to="volumes")],
            **{
                # `@` separates the layer from the port terminal it belongs to
                f"bw@{port.name}": [ConstantInField(resolution=20, apply_to="volumes")]
                for port in c.ports
            },
        },
    ),
)
assert all(1e-15 < results.capacitance_matrix[port.name, port.name] < 1e-10 for port in c.ports)
print(results.capacitance_matrix)

# %% [markdown]
# ## Bibliography
#
# ```{bibliography}
# :style: unsrt
# :filter: docname in docnames
# ```
